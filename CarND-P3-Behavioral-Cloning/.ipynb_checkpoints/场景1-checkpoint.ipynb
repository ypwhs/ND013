# %%
from keras.layers import *
from keras.models import *
from keras.optimizers import *

import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

from keras.backend.tensorflow_backend import set_session
import tensorflow as tf

config = tf.ConfigProto()
config.gpu_options.allow_growth=True
set_session(tf.Session(config=config))
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('driving_log.csv')
df.columns = ['center', 'left', 'right', 'dir', 'acc', 'nacc', 'speed']
print df['speed'].mean(), df['dir'].mean(), df['dir'].max(), df['dir'].min(), (df['dir'] > 0).mean()
df.head()
# Out:
# 30.1886584535 -0.0341753267311 1.0 -1.0 0.221866576819
#                                               center  \
# 0  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 1  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 2  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 3  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 4  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
#
#                                                 left  \
# 0  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 1  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 2  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 3  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
# 4  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/...
#
#                                                right       dir  acc  nacc  \
# 0  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/... -0.105882    1     0
# 1  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/... -0.105882    1     0
# 2  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/... -0.105882    1     0
# 3  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/... -0.105882    1     0
# 4  /home/ypw/Desktop/CarND-P3-Behavioral-Cloning/... -0.105882    1     0
#
#       speed
# 0  30.19015
# 1  30.18984
# 2  30.18810
# 3  30.19030
# 4  30.18988

# %%
img = cv2.imread(df['center'][0])
print img.shape
img = img[50:-20,:]
plt.imshow(img[:,:,::-1])
# Out:
# (160, 320, 3)

# %%
n = len(df)
X = np.zeros((n, 160, 320, 3), dtype=np.uint8)
y = df['dir'].values

for i in tqdm(range(n)):
    X[i] = cv2.imread(df['center'][i])[:,:,::-1]
# Out:
# 100%|██████████| 5936/5936 [00:04<00:00, 1299.34it/s]

# %%
X = np.concatenate([X, X[:,::-1]], axis=0)
y = np.concatenate([y, -y], axis=0)

# %%
from sklearn.utils import shuffle

X, y = shuffle(X, y)

# %%
inputs = Input(X.shape[1:])

x = inputs
x = Cropping2D(((50, 20), (0, 0)))(x)
x = Lambda(lambda x:x/255-0.5)(x)
for i in range(4):
    for j in range(2):
        x = Conv2D(32, 3, activation='relu')(x)
    x = MaxPooling2D(2)(x)

x = Flatten()(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(1, activation='tanh')(x)

model = Model(inputs, x)
model.compile(loss='mse', optimizer='adam')

# %%
# SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))

# %%
model.fit(X, y, batch_size=128, epochs=10, validation_split=0.2)
# Out:
# Train on 9497 samples, validate on 2375 samples
# Epoch 1/10
# 9497/9497 [==============================] - 18s - loss: 0.0114 - val_loss: 0.0125
# Epoch 2/10
# 9497/9497 [==============================] - 16s - loss: 0.0088 - val_loss: 0.0089
# Epoch 3/10
# 9497/9497 [==============================] - 16s - loss: 0.0077 - val_loss: 0.0095
# Epoch 4/10
# 9497/9497 [==============================] - 17s - loss: 0.0074 - val_loss: 0.0091
# Epoch 5/10
# 9497/9497 [==============================] - 16s - loss: 0.0071 - val_loss: 0.0080
# Epoch 6/10
# 9497/9497 [==============================] - 16s - loss: 0.0068 - val_loss: 0.0082
# Epoch 7/10
# 9497/9497 [==============================] - 16s - loss: 0.0065 - val_loss: 0.0077
# Epoch 8/10
# 9497/9497 [==============================] - 16s - loss: 0.0069 - val_loss: 0.0073
# Epoch 9/10
# 9497/9497 [==============================] - 16s - loss: 0.0063 - val_loss: 0.0074
# Epoch 10/10
# 9497/9497 [==============================] - 16s - loss: 0.0062 - val_loss: 0.0075

# %%
model.save('model.h5')

# %%
index = np.random.choice(n, 128)
y_pred = model.predict(X[index])[:,0]
print ((y_pred > 0) == (y[index] > 0)).mean()
list(zip(y_pred, y[index]))[:32]
# Out:
# 0.765625
# [(0.032910291, -0.0),
#  (0.11344694, 0.058823529999999999),
#  (-0.09821327, -0.094117649999999997),
#  (-0.073095828, -0.37058819999999998),
#  (0.080444895, 0.10588239999999999),
#  (-0.054228723, 0.0),
#  (-0.010315508, -0.0),
#  (0.014081549, -0.04117647),
#  (0.0098615, 0.1176471),
#  (-0.042041659, -0.029411759999999999),
#  (0.059298556, 0.058823529999999999),
#  (0.014406696, 0.017647059999999999),
#  (0.05541423, 0.058823529999999999),
#  (-0.05626788, -0.04117647),
#  (-0.026125511, 0.0058823530000000008),
#  (0.11344694, 0.058823529999999999),
#  (0.082221366, 0.0058823530000000008),
#  (-0.12671714, -0.094117649999999997),
#  (-0.053903598, 0.0),
#  (-0.038384695, 0.088235289999999994),
#  (-0.041509405, -0.088235289999999994),
#  (0.22471774, 0.35882350000000002),
#  (0.047455598, 0.070588239999999997),
#  (-0.030368147, -0.052941179999999997),
#  (0.015810527, 0.011764709999999999),
#  (-0.10786264, -0.26470589999999999),
#  (0.079759233, 0.094117649999999997),
#  (0.048231713, -0.0),
#  (-0.020528154, -0.0),
#  (0.0020589498, 0.035294119999999998),
#  (-0.029225959, -0.0058823530000000008),
#  (0.0150128, 0.029411759999999999)]
